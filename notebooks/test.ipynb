# %% [markdown]
# # Figures

# %%
import matplotlib.pyplot as plt

# %%
# first graph - AUROC curve of ClinVar at different context lengths

plt.xlabel("Context Length")
plt.ylabel("AUROC")

plt.title("ClinVar pathogenic vs. gnomAD common (missense) across context lengths")

plt.plot([128, 512, 1024], [0.969, 0.971, 0.973], label="GPN-MSA")
plt.plot([128, 512, 1024], [0.963, 0.966, 0.967], label="CADD")
plt.plot([128, 512, 1024], [0.944, 0.952, 0.963], label="ESM-1B")
plt.plot([128, 512, 1024], [0.923, 0.947, 0.952], label="phyloP-100v")
plt.plot([128, 512, 1024], [0.874, 0.894, 0.893], label="phastCons-100v")

plt.plot([128, 512, 1024], [0.919, 0.952, 0.968], label="MSAMamba")

plt.legend()

# %%
# first graph - AUROC curve of ClinVar at different context lengths
from matplotlib.patches import Patch

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 5))

ax1.set_xlabel("Context Length")
ax1.set_ylabel("AUROC")

ax1.set_title("ClinVar pathogenic vs. gnomAD common\n(missense) across context lengths")

ax1.plot([128, 512, 1024], [0.969, 0.968, 0.957], label="GPN-MSA", color="red")
ax1.plot([128, 512, 1024], [0.963, 0.954, 0.942], label="CADD", color="orange")
# ax1.plot([128, 512, 1024], [0.944, 0.962, 0.975], label="ESM-1B", color="yellow")
ax1.plot([128, 512, 1024], [0.923, 0.925, 0.926], label="phyloP-100v", color="green")
ax1.plot([128, 512, 1024], [0.874, 0.894, 0.893], label="phastCons-100v", color="purple")

ax1.plot([128, 512, 1024], [0.919, 0.966, 0.979], label="MSAMamba", color="xkcd:sky blue")

ax2.set_xlabel("Context Length")
ax2.set_ylabel("AUPRC")

ax2.set_title("OMIM pathogenic vs. gnomAD common\n(missense) across context lengths")

ax2.plot([128, 512, 1024], [0.127, 0.128, 0.119], label="GPN-MSA", color="red")
ax2.plot([128, 512, 1024], [0.048, 0.055, 0.057], label="CADD", color="orange")
ax2.plot([128, 512, 1024], [0.038, 0.042, 0.045], label="phyloP-100v", color="green")
ax2.plot([128, 512, 1024], [0.006, 0.011, 0.011], label="phastCons-100v", color="purple")

ax2.plot([128, 512, 1024], [0.102, 0.130, 0.137], label="MSAMamba", color="xkcd:sky blue")

handles = [Patch(color="red", label="GPN-MSA"), 
           Patch(color="orange", label="CADD"), 
           Patch(color="green", label="phyloP-100v"), 
           Patch(color="purple", label="phastCons-100v"), 
           Patch(color="xkcd:sky blue", label="MSAMamba"), ]

fig.legend(handles=handles)
